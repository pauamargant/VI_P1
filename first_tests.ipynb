# %%
import pandas as pd
import altair as alt

# %%
df = pd.read_csv('dataset_v1.csv', parse_dates=['CRASH DATE'])
df.head()
# Out:
#                  CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  \
# 0 2020-09-06 00:00:00+00:00      18:05        NaN       NaN  40.771038
# 1 2020-09-20 00:00:00+00:00       9:14        NaN       NaN  40.722095
# 2 2020-09-24 00:00:00+00:00      22:00  MANHATTAN   10039.0  40.824757
# 3 2020-08-06 00:00:00+00:00       5:30        NaN       NaN        NaN
# 4 2020-08-01 00:00:00+00:00      17:16      BRONX   10462.0  40.840508
#
#    LONGITUDE                LOCATION         ON STREET NAME CROSS STREET NAME  \
# 0  -73.83413  (40.771038, -73.83413)  WHITESTONE EXPRESSWAY               NaN
# 1  -73.77772  (40.722095, -73.77772)     GRAND CENTRAL PKWY               NaN
# 2  -73.94052  (40.824757, -73.94052)               8 AVENUE   WEST 148 STREET
# 3        NaN                     NaN                    NaN               NaN
# 4  -73.85515  (40.840508, -73.85515)    METROPOLITAN AVENUE      LINDEN DRIVE
#
# ...

# %%
print(df.dtypes)
# Out:
# CRASH DATE                       datetime64[ns, UTC]
# CRASH TIME                                    object
# BOROUGH                                       object
# ZIP CODE                                     float64
# LATITUDE                                     float64
# LONGITUDE                                    float64
# LOCATION                                      object
# ON STREET NAME                                object
# CROSS STREET NAME                             object
# OFF STREET NAME                               object
# NUMBER OF PERSONS INJURED                    float64
# NUMBER OF PERSONS KILLED                     float64
# NUMBER OF PEDESTRIANS INJURED                  int64
# NUMBER OF PEDESTRIANS KILLED                   int64
# NUMBER OF CYCLIST INJURED                      int64
# NUMBER OF CYCLIST KILLED                       int64
# NUMBER OF MOTORIST INJURED                     int64
# NUMBER OF MOTORIST KILLED                      int64
# ...

# %%
# count values in VEHICHE TYPE CODE 1
df['VEHICLE TYPE CODE 1'].value_counts()[0:20]
# Out:
# Sedan                54025
# SUV                  40659
# Taxi                  4806
# truck                 3899
# pickup                3245
# Bike                  1938
# bus                   1416
# Motorbike             1183
# van                    824
# ambulance              468
# Convertible            411
# E-Scooter              239
# pick up                236
# Flat Bed               232
# Garbage or Refuse      193
# e-bike                 146
# Carry All              146
# motorbike              135
# Chassis Cab             83
# fire truck              77
# Name: VEHICLE TYPE CODE 1, dtype: int64

# %%
# join e-bike and BIKE 
df['VEHICLE TYPE CODE 1'] = df['VEHICLE TYPE CODE 1'].replace('e-bike', 'BIKE')
# replace motorbike and E-scooter

# %%
# count nans
print(df.isna().sum())
# Out:
# CRASH DATE                            0
# CRASH TIME                            0
# BOROUGH                           40671
# ZIP CODE                          40686
# LATITUDE                           7667
# LONGITUDE                          7667
# LOCATION                           7667
# ON STREET NAME                    29464
# CROSS STREET NAME                 60179
# OFF STREET NAME                   86502
# NUMBER OF PERSONS INJURED             2
# NUMBER OF PERSONS KILLED              4
# NUMBER OF PEDESTRIANS INJURED         0
# NUMBER OF PEDESTRIANS KILLED          0
# NUMBER OF CYCLIST INJURED             0
# NUMBER OF CYCLIST KILLED              0
# NUMBER OF MOTORIST INJURED            0
# NUMBER OF MOTORIST KILLED             0
# CONTRIBUTING FACTOR VEHICLE 1       351
# CONTRIBUTING FACTOR VEHICLE 2     19593
# CONTRIBUTING FACTOR VEHICLE 3    106611
# CONTRIBUTING FACTOR VEHICLE 4    113552
# CONTRIBUTING FACTOR VEHICLE 5    115126
# ...
